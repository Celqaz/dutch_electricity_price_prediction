# %% [markdown]
# # EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_theme()

# %% [markdown]
# ## Load data

# %%
df = pd.read_pickle('../data/data.pkl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17520 entries, 2022-01-01 01:00:00 to 2024-01-01 00:00:00
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   solar          17520 non-null  int64
#  1   wind_offshore  17520 non-null  int64
#  2   wind_onshore   17520 non-null  int64
#  3   total_load     17520 non-null  int64
#  4   price          17520 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 821.2 KB

# %%
df.describe().round(2)
# Out:
#           solar  wind_offshore  wind_onshore  total_load     price
# count  17520.00       17520.00      17520.00    17520.00  17520.00
# mean    5102.07        2622.89       6855.02    43650.04    241.92
# std     7380.08        1994.46       5748.27     9299.06    131.53
# min        0.00          23.00         63.00     1915.00   -222.36
# 25%        0.00         834.00       2091.00    39456.00    160.00
# 50%      372.00        2112.00       5208.00    44338.00    217.00
# 75%     8685.00        4375.00      10509.25    49335.25    304.94
# max    31286.00        6664.00      25740.00    85027.00    871.00

# %%
plt.figure(figsize=(15,8))
g = sns.lineplot(data=df, x=df.index, y='price')  # Plot on current subplot
g.set_title(f"\nBasic Time Series of Zone\n", fontsize=12)  # Set title with zone name

# Adjust overall layout (optional)
plt.tight_layout()  # Adjust spacing between subplots

# Display the figure
plt.show()

# %% [markdown]
# # LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data = df.filter(['price'])
dataset = data.values
training_data_len = int(np.ceil( len(dataset) * .95 ))
training_data_len
# Out:
# 16644

# %%
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.31742518],
#        [0.31742518],
#        [0.32593107],
#        ...,
#        [0.21699166],
#        [0.21246433],
#        [0.20484561]])

# %%
# Create the training data set 
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.31742518, 0.31742518, 0.32593107, 0.25715226, 0.23782652,
#        0.23968318, 0.24049718, 0.2429392 , 0.24879271, 0.26744165,
#        0.27360613, 0.28029194, 0.29002341, 0.29190751, 0.29224592,
#        0.29599583, 0.31916295, 0.34053743, 0.33720824, 0.33167484,
#        0.31484598, 0.29722141, 0.29251116, 0.28126143, 0.25557913,
#        0.25147253, 0.24816163, 0.23532963, 0.23040901, 0.23444245,
#        0.23494549, 0.24160386, 0.24814334, 0.25825894, 0.26747823,
#        0.26397527, 0.26240214, 0.24632326, 0.24824395, 0.27195983,
#        0.28111509, 0.29483427, 0.30388893, 0.29474281, 0.2737982 ,
#        0.24559157, 0.24571047, 0.23349126, 0.20365662, 0.20336394,
#        0.20330907, 0.20241275, 0.20245848, 0.20337309, 0.23627168,
#        0.28599912, 0.31312651, 0.32218117, 0.31224848, 0.31238567])]
# [0.3131265091095339]
#
# [array([0.31742518, 0.31742518, 0.32593107, 0.25715226, 0.23782652,
#        0.23968318, 0.24049718, 0.2429392 , 0.24879271, 0.26744165,
#        0.27360613, 0.28029194, 0.29002341, 0.29190751, 0.29224592,
#        0.29599583, 0.31916295, 0.34053743, 0.33720824, 0.33167484,
#        0.31484598, 0.29722141, 0.29251116, 0.28126143, 0.25557913,
#        0.25147253, 0.24816163, 0.23532963, 0.23040901, 0.23444245,
#        0.23494549, 0.24160386, 0.24814334, 0.25825894, 0.26747823,
#        0.26397527, 0.26240214, 0.24632326, 0.24824395, 0.27195983,
#        0.28111509, 0.29483427, 0.30388893, 0.29474281, 0.2737982 ,
#        0.24559157, 0.24571047, 0.23349126, 0.20365662, 0.20336394,
#        0.20330907, 0.20241275, 0.20245848, 0.20337309, 0.23627168,
#        0.28599912, 0.31312651, 0.32218117, 0.31224848, 0.31238567]), array([0.31742518, 0.32593107, 0.25715226, 0.23782652, 0.23968318,
#        0.24049718, 0.2429392 , 0.24879271, 0.26744165, 0.27360613,
#        0.28029194, 0.29002341, 0.29190751, 0.29224592, 0.29599583,
#        0.31916295, 0.34053743, 0.33720824, 0.33167484, 0.31484598,
#        0.29722141, 0.29251116, 0.28126143, 0.25557913, 0.25147253,
#        0.24816163, 0.23532963, 0.23040901, 0.23444245, 0.23494549,
#        0.24160386, 0.24814334, 0.25825894, 0.26747823, 0.26397527,
#        0.26240214, 0.24632326, 0.24824395, 0.27195983, 0.28111509,
#        0.29483427, 0.30388893, 0.29474281, 0.2737982 , 0.24559157,
#        0.24571047, 0.23349126, 0.20365662, 0.20336394, 0.20330907,
#        0.20241275, 0.20245848, 0.20337309, 0.23627168, 0.28599912,
#        0.31312651, 0.32218117, 0.31224848, 0.31238567, 0.31312651])]
# [0.3131265091095339, 0.3155227921270213]

# %% [markdown]
# ## LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 2024-10-20 22:40:16.349058: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/libin/anaconda3/envs/th/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16584/16584 ━━━━━━━━━━━━━━━━━━━━ 278s 17ms/step - loss: 0.0026

# %%
# Create the testing data set
test_data = scaled_data[training_data_len - 60: , :]
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# 32.70220864855038

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(20,5))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Price (cents/kWh)', fontsize=18)
plt.plot(train['price'])
plt.plot(valid[['price', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions (cents/kWh)'], loc='upper right')
plt.show()
# Out:
# /var/folders/8k/8n8mf6jn28537sc4vvz36rhh0000gn/T/ipykernel_91434/3791943124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
valid['Error'] = valid['price'] - valid['Predictions']
valid.head(25).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Comic Sans MS',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# /var/folders/8k/8n8mf6jn28537sc4vvz36rhh0000gn/T/ipykernel_91434/3947543293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Error'] = valid['price'] - valid['Predictions']
# <style type="text/css">
# #T_7eb10_row0_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row0_col1, #T_7eb10_row11_col2, #T_7eb10_row16_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row0_col2 {
#   background-color: #f7a98b;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row1_col0, #T_7eb10_row24_col0 {
#   background-color: #adc9fd;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row1_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row1_col2, #T_7eb10_row5_col0, #T_7eb10_row6_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row2_col0, #T_7eb10_row3_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row2_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row2_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row3_col1, #T_7eb10_row7_col0 {
#   background-color: #f7b79b;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row3_col2 {
#   background-color: #8db0fe;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row4_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row4_col1, #T_7eb10_row9_col2 {
#   background-color: #f4c6af;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row4_col2 {
#   background-color: #f39577;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row5_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row5_col2, #T_7eb10_row21_col2 {
#   background-color: #dddcdc;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row6_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row6_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row7_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row7_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row8_col0 {
#   background-color: #d7dce3;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row8_col1 {
#   background-color: #e2dad5;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row8_col2, #T_7eb10_row15_col2, #T_7eb10_row23_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row9_col0, #T_7eb10_row13_col2 {
#   background-color: #cfdaea;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row9_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row10_col0, #T_7eb10_row21_col1 {
#   background-color: #d6dce4;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row10_col1, #T_7eb10_row18_col2 {
#   background-color: #aec9fc;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row10_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row11_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row11_col1, #T_7eb10_row12_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row12_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row12_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row13_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row13_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row14_col0, #T_7eb10_row15_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row14_col1, #T_7eb10_row22_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row14_col2, #T_7eb10_row19_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row15_col1, #T_7eb10_row16_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row16_col2 {
#   background-color: #98b9ff;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row17_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row17_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row17_col2 {
#   background-color: #d8dce2;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row18_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row18_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row19_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row19_col2, #T_7eb10_row22_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row20_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row20_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row20_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row21_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row22_col0 {
#   background-color: #bed2f6;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row23_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row23_col2, #T_7eb10_row24_col2 {
#   background-color: #dedcdb;
#   color: #000000;
#   font-family: Comic Sans MS;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_7eb10_row24_col1 {
#   background-color: #9bbcff;
#   color: #000000;
#   font-family: Comic Sa
