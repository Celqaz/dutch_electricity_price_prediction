# %% [markdown]
# # EWT LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, Flatten, Input, Conv1D, MaxPooling1D
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy.fft import fft, ifft
# Out:
# 2024-11-27 19:47:12.382879: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
import numpy as np
import random

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
# %run utils.ipynb

# %%
df_ori = load_data('df_actual_22_24_cleaned')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24840 entries, 2022-01-01 01:00:00 to 2024-11-01 00:00:00
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   price                    24840 non-null  float64
#  1   solar                    24840 non-null  int64
#  2   wind_onshore             24840 non-null  int64
#  3   wind_offshore            24840 non-null  int64
#  4   total_load               24840 non-null  int64
#  5   actual_solar             24840 non-null  int64
#  6   actual_wind_onshore      24840 non-null  int64
#  7   actual_wind_offshore     24840 non-null  int64
#  8   actual_fossil_gas        24840 non-null  int64
#  9   actual_fossil_hard_coal  24840 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 2.1 MB
# None

# %%
fig= plt.subplots(figsize=(16, 8))
plt.plot(df_ori['price'], label="Original Signal", linewidth=1.5)

# %% [markdown]
# # EWT

# %%
SEQ = 24

# %%
features = ['price'] 
df_ewt = df_ori.loc['2021': '2024',  features]

# %%
def train_test_split_th(df, features =['price'], train_period = ['2022', '2023'], test_period = ['2024', '2024']): 
    train_start, train_end = train_period
    test_start, test_end = test_period
    df_ewt = df_ori.loc[train_start: test_end,  features]
    
    train_df = df.loc[train_start: train_end]
    test_df = df.loc[test_start: test_end]

    return train_df, test_df

# %%
train_df_ewt, test_df_ewt = train_test_split_th(df_ori, features =['price'], train_period = ['2022', '2023'], test_period =  ['2024', '2024'])

# %%
print('train shape', train_df_ewt.shape)
print('test shape', test_df_ewt.shape)
# Out:
# train shape (17519, 10)
# test shape (7321, 10)

# %%
def ewt_trans(data, level = 4, lengthFilter=10, reg='none', sigmaFilter=5):

    # return reconstructed signal and components
    sig_combined, sig_comps = ewt_decompose(data, level, lengthFilter= lengthFilter, reg = reg, sigmaFilter = sigmaFilter)
    
    eva_s(data.to_numpy(), sig_combined)
    fig, ax= plt.subplots(figsize=(16, 8))
    plt.plot(data.to_numpy()[:200], label = 'Actual',alpha = 0.7)
    plt.plot(sig_combined[:200], label = 'Simulated', alpha = 0.7)
    ax.legend(loc=2)

    return sig_comps

# %%
sig_comps = ewt_trans(df_ewt['price'], level = 6, lengthFilter= 1, reg = 'none', sigmaFilter=5)
# Out:
# Mean Absolute Error (MAE): 7.87
# Root Mean Squared Error (RMSE): 11.51
# Symmetric Mean Absolute Percentage Error (sMAPE): 13.93
# sMAPE: 47.27

# %%
sig_comps.shape
# Out:
# (24840, 6)

# %%
fig, axes= plt.subplots(7,1, figsize=(16, 16))
axes[0].plot(df_ewt, label = 'Original Data')
axes[0].legend(loc=2)
for i in range(sig_comps.shape[1]):
    axes[i+1].plot(sig_comps[:,i], label = f'Decomposed Series {i+1}')
    axes[i + 1].legend(loc=2)

# Add a common ylabel and xlabel for the entire figure
fig.text(0.04, 0.5, 'Day-ahead Electricity Price (EUR/MWh)', va='center', rotation='vertical', fontsize=12)
fig.text(0.5, 0.04, 'Time/h', ha='center', fontsize=12)

# Adjust spacing
plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])
file_name = 'ewt_decompose'
plt.savefig(f'eda_plot/{file_name}.png', dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Models

# %%
def lstm_model_ewt(train_data, test_data):
    # Step 3: Normalize each component separately
    scaler = MinMaxScaler()
    # train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    # test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    # train_scaled = train_data.reshape(-1, 1)
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `window_size` steps across all components
            y.append(data[i + seq_length, 0])
    
        return np.array(X), np.array(y)
    
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)# Step 5: Define the LSTM model
    
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(units=64, return_sequences=True),
        Dropout(0.2),
        LSTM(units=32, return_sequences=False),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)
    # Predict
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    
    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled,y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
def gru_model_ewt(train_data, test_data):

    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `window_size` steps across all components
            y.append(data[i + seq_length, 0])
    
        return np.array(X), np.array(y)
    
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 5: Define the GRU model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        GRU(units=64, return_sequences=True),
        Dropout(0.2),
        GRU(units=32, return_sequences=False),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)

    # Rescale predictions
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled,y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
def cnn_model_ewt(train_data, test_data):
    
    # Step 3: Normalize each component separately
    scaler = MinMaxScaler()
    # scaler = StandardScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `window_size` steps across all components
            y.append(data[i + seq_length, 0])
    
        return np.array(X), np.array(y)
    
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 5: Define the CNN model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        Dropout(0.2),
        Conv1D(filters=32, kernel_size=3, activation='relu'),
        Flatten(),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)

    # Rescale predictions
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled, y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
def cnn_lstm_model_ewt(train_data, test_data):
    # Step 3: Normalize each component separately
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `seq_length` steps across all components
            y.append(data[i + seq_length, 0])
        return np.array(X), np.array(y)
    
    # Create sequences
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 5: Define the CNN-LSTM model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        LSTM(units=64, return_sequences=True),
        Dropout(0.2),
        LSTM(units=32, return_sequences=False),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)
    
    # Rescale predictions and actual values back to original scale
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    # Evaluate the performance
    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled, y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
def cnn_model_ewt_2(train_data, test_data):
    # Step 3: Normalize each component separately
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `seq_length` steps across all components
            y.append(data[i + seq_length, 0])
        return np.array(X), np.array(y)
    
    # Create sequences
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 5: Define the CNN-LSTM model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        LSTM(units=64, return_sequences=True),
        Dropout(0.2),
        LSTM(units=32, return_sequences=False),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)
    
    # Rescale predictions and actual values back to original scale
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    # Evaluate the performance
    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled, y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
from keras.models import Model, Sequential
from keras.layers import Input, LSTM, Dense, Dropout, Multiply, Lambda
# from sklearn.preprocessing import MinMaxScaler
import numpy as np
import keras.backend as K

def lstm_am_model_ewt(train_data, test_data):
    # Step 1: Normalize each component separately
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    # Step 2: Create sequences for training and testing
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `seq_length` steps
            y.append(data[i + seq_length, 0])   # Target value
        return np.array(X), np.array(y)
    
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 3: Define Attention Layer
    def attention_layer(inputs):
        """
        Attention mechanism to focus on relevant parts of the sequence.
        """
        attention_scores = Dense(1, activation='tanh')(inputs)  # Score for each time step
        attention_scores = Lambda(lambda x: K.softmax(x, axis=1))(attention_scores)  # Normalize scores
        context_vector = Multiply()([inputs, attention_scores])  # Weighted input
        context_vector = Lambda(lambda x: K.sum(x, axis=1))(context_vector)  # Sum over time steps
        return context_vector

    # Step 4: Define the LSTM model with Attention
    inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))
    lstm_out = LSTM(64, return_sequences=True)(inputs)  # LSTM layer
    lstm_out = Dropout(0.2)(lstm_out)
    context_vector = attention_layer(lstm_out)  # Apply Attention
    outputs = Dense(1)(context_vector)  # Final Dense layer for prediction
    model = Model(inputs, outputs)
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Step 5: Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32)

    # Step 6: Predict
    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)

    # Step 7: Rescale predictions back to original scale
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    # Step 8: Evaluate the performance
    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled, y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
def cnn_model_ewt_2(train_data, test_data):
    # Step 3: Normalize each component separately
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `seq_length` steps across all components
            y.append(data[i + seq_length, 0])
        return np.array(X), np.array(y)
    
    # Create sequences
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 5: Define the CNN-LSTM model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        LSTM(units=64, return_sequences=True),
        Dropout(0.2),
        LSTM(units=32, return_sequences=False),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)
    
    # Rescale predictions and actual values back to original scale
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    # Evaluate the performance
    mae, rsme, mape = eva_s(y_test_rescaled, y_pred_rescaled)

    y_test_preds = [y_test_rescaled, y_pred_rescaled]
    performance = [mae, rsme, mape]

    return model, y_test_preds, performance, train_pred_rescaled

# %%
def cnn_model_ewt_revised(train_data, test_data):
    # Step 3: Normalize each component separately
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
    test_scaled = scaler.transform(test_data.reshape(-1, 1))
    
    def create_seq(data, seq_length=24):
        X, y = [], []
        for i in range(len(data) - seq_length):
            X.append(data[i:i + seq_length, :])  # Previous `seq_length` steps across all components
            y.append(data[i + seq_length, 0])
        return np.array(X), np.array(y)
    
    # Create sequences
    X_train, y_train = create_seq(train_scaled, 24)
    X_test, y_test = create_seq(test_scaled, 24)

    # Step 5: Define the CNN-LSTM model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        LSTM(units=64, return_sequences=True),
        Dropout(0.2),
        LSTM(units=32, return_sequences=False),
        Dense(units=1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

    print('Predict on X_test.')
    y_pred = model.predict(X_test)
    
    print('Predict on X_train.')
    train_pred = model.predict(X_train)
    
    # Rescale predictions and actual values back to original scale
    y_pred_rescaled = scaler.inverse_transform(y_pred.reshape(-1, 1))
    y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
    train_pred_rescaled = scaler.inverse_transform(train_pred.reshape(-1, 1))

    # Evaluate the performance
    mae, rsme, mape, smape = eva_s(y_test_rescaled.reshape(-1), y_pred_rescaled.reshape(-1))

    y_test_preds = [y_test_rescaled, y_pred_rescaled]
    performance = [mae, rsme, mape,smape]

    return model, y_test_preds, performance, train_pred_rescaled

# %% [markdown]
# ## Training

# %%
trian_len = train_df_ewt.shape[0] 
train_comps = sig_comps[:trian_len, :]
test_comps = sig_comps[trian_len:, :]

# %%
models_invetory = {
    # 'LSTM': lstm_model_ewt,
    # 'GRU' : gru_model_ewt,
    'CNN_R' : cnn_model_ewt_revised
}

# %%
for model_name, model_func in models_invetory.items():
    print('Model:', model_name)
    root_dir = f'ewt_models/{model_name}'
    print(root_dir)

    # container
    models = []
    test_preds =[]
    metrics = []
    train_preds = []
    for i in range(sig_comps.shape[1]):
        # for i in range(1):
        print('Training on components:',i)
        train_data = train_comps[:,i]
        test_data = test_comps[:,i]
        model, y_test_preds, performance, trian_pred_rescaled = model_func(train_data, test_data)

        comp_model_name = f'ewt_{model_name}_comp_{i}'
        model.save(f'{root_dir}/{comp_model_name}.keras')
        print('Model saved!')
        models.append(model)
        test_preds.append(y_test_preds)
        metrics.append(performance)
        train_preds.append(trian_pred_rescaled)

    root_dir = f'ewt_models/{model_name}'
    np.save(f"{root_dir}/{model_name}_test_preds.npy", np.array(test_preds))
    np.save(f"{root_dir}/{model_name}_metrics.npy", np.array(metrics))
    np.save(f"{root_dir}/{model_name}_train_preds.npy", np.array(train_preds))
# Out:
# Model: CNN_R
# ewt_models/CNN_R
# Training on components: 0
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_18 (Conv1D)              │ (None, 22, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_12 (MaxPooling1D) │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_20 (LSTM)                  │ (None, 11, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_21 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,729 (178.63 KB)
#  Trainable params: 45,729 (178.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.0301 - val_loss: 5.5937e-05
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 2.6677e-04 - val_loss: 5.7516e-05
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.9137e-04 - val_loss: 8.5496e-05
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.5663e-04 - val_loss: 8.1423e-05
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.6174e-04 - val_loss: 1.1593e-04
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0652e-04 - val_loss: 1.0699e-04
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0923e-04 - val_loss: 8.2193e-05
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 1.0091e-04 - val_loss: 1.0281e-04
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.0827e-05 - val_loss: 8.5366e-05
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 7.0784e-05 - val_loss: 9.3463e-05
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0219e-04 - val_loss: 1.1277e-04
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 7.1572e-05 - val_loss: 1.2329e-04
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.8115e-05 - val_loss: 1.1848e-04
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.7518e-05 - val_loss: 1.3240e-04
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 8.2119e-05 - val_loss: 8.6011e-05
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 8.2106e-05 - val_loss: 1.1080e-04
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 7.1112e-05 - val_loss: 1.4437e-04
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 5.8599e-05 - val_loss: 1.2965e-04
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 5.2752e-05 - val_loss: 8.1479e-05
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 4.9822e-05 - val_loss: 8.4229e-05
# Predict on X_test.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Predict on X_train.
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Mean Absolute Error (MAE): 16.69
# Root Mean Squared Error (RMSE): 18.69
# Symmetric Mean Absolute Percentage Error (sMAPE): 21.82
# sMAPE: 21.75
# Model saved!
# Training on components: 1
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_19 (Conv1D)              │ (None, 22, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_13 (MaxPooling1D) │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_22 (LSTM)                  │ (None, 11, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_23 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,729 (178.63 KB)
#  Trainable params: 45,729 (178.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0082 - val_loss: 1.3700e-06
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.7882e-04 - val_loss: 3.4563e-06
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.4410e-04 - val_loss: 1.4302e-06
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.1077e-04 - val_loss: 3.5770e-06
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.8031e-05 - val_loss: 3.2453e-05
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.4237e-05 - val_loss: 2.9985e-07
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.1154e-05 - val_loss: 1.3229e-06
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 7.6243e-05 - val_loss: 2.5200e-05
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.3869e-05 - val_loss: 1.7924e-05
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.2285e-05 - val_loss: 2.9893e-05
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 7.6331e-05 - val_loss: 8.7195e-06
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 6.2557e-05 - val_loss: 1.6616e-06
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 6.8647e-05 - val_loss: 1.7800e-05
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.3738e-05 - val_loss: 1.9780e-05
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.0512e-05 - val_loss: 8.4719e-06
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.1927e-05 - val_loss: 8.6284e-05
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 4.9723e-05 - val_loss: 2.8763e-05
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.3797e-05 - val_loss: 3.2461e-07
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 4.2061e-05 - val_loss: 5.9582e-08
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.3776e-05 - val_loss: 7.2116e-06
# Predict on X_test.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Predict on X_train.
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Mean Absolute Error (MAE): 0.66
# Root Mean Squared Error (RMSE): 0.66
# Symmetric Mean Absolute Percentage Error (sMAPE): 65.88
# sMAPE: 65.68
# Model saved!
# Training on components: 2
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_20 (Conv1D)              │ (None, 22, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_14 (MaxPooling1D) │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_24 (LSTM)                  │ (None, 11, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_25 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,729 (178.63 KB)
#  Trainable params: 45,729 (178.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.0140 - val_loss: 5.2581e-05
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.4843e-04 - val_loss: 5.4831e-05
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.8289e-04 - val_loss: 2.6976e-05
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 2.0704e-04 - val_loss: 1.8261e-05
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1.4091e-04 - val_loss: 5.7622e-06
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.0030e-05 - val_loss: 1.7825e-05
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 5.7755e-05 - val_loss: 5.9718e-06
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 5.3170e-05 - val_loss: 4.0046e-06
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.8507e-05 - val_loss: 5.8994e-05
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 5.5575e-05 - val_loss: 6.2631e-05
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 2.8504e-05 - val_loss: 1.0216e-05
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.6667e-05 - val_loss: 6.0906e-07
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.0623e-05 - val_loss: 5.4256e-06
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.7962e-05 - val_loss: 1.6686e-06
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.6787e-05 - val_loss: 1.1915e-06
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.9818e-05 - val_loss: 9.3154e-07
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 3.5481e-05 - val_loss: 1.8881e-05
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.4528e-05 - val_loss: 2.0862e-05
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.1541e-05 - val_loss: 6.3984e-05
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.3279e-05 - val_loss: 5.3692e-06
# Predict on X_test.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Predict on X_train.
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Mean Absolute Error (MAE): 0.78
# Root Mean Squared Error (RMSE): 0.80
# Symmetric Mean Absolute Percentage Error (sMAPE): 26.26
# sMAPE: 26.18
# Model saved!
# Training on components: 3
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_21 (Conv1D)              │ (None, 22, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_15 (MaxPooling1D) │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_26 (LSTM)                  │ (None, 11, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_27 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,729 (178.63 KB)
#  Trainable params: 45,729 (178.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0248 - val_loss: 1.9905e-04
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.6102e-04 - val_loss: 1.6503e-04
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 5.3075e-04 - val_loss: 7.3305e-05
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.0090e-04 - val_loss: 2.9196e-05
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.1156e-04 - val_loss: 5.9074e-05
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.4662e-04 - val_loss: 2.9624e-05
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0627e-04 - val_loss: 9.5578e-05
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.0927e-04 - val_loss: 6.0446e-06
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.7933e-05 - val_loss: 1.5641e-05
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.7215e-05 - val_loss: 3.9717e-06
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.5017e-05 - val_loss: 6.5693e-06
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.7199e-05 - val_loss: 1.6358e-05
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 5.0349e-05 - val_loss: 2.4041e-05
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.9659e-05 - val_loss: 4.8429e-06
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 4.5432e-05 - val_loss: 3.3295e-06
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.2066e-05 - val_loss: 5.9148e-06
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 3.7541e-05 - val_loss: 2.5398e-05
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.0766e-05 - val_loss: 1.7238e-05
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.7641e-05 - val_loss: 2.9706e-06
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.2937e-05 - val_loss: 2.4575e-06
# Predict on X_test.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Predict on X_train.
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error (MAE): 0.45
# Root Mean Squared Error (RMSE): 0.55
# Symmetric Mean Absolute Percentage Error (sMAPE): 9.79
# sMAPE: 9.76
# Model saved!
# Training on components: 4
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_22 (Conv1D)              │ (None, 22, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_16 (MaxPooling1D) │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_28 (LSTM)                  │ (None, 11, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_29 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,729 (178.63 KB)
#  Trainable params: 45,729 (178.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0224 - val_loss: 3.5915e-04
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0014 - val_loss: 1.6280e-04
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 5.3972e-04 - val_loss: 2.8805e-05
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.9304e-04 - val_loss: 3.2129e-05
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.8959e-04 - val_loss: 5.7281e-05
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.8053e-04 - val_loss: 1.1985e-04
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.3358e-04 - val_loss: 1.5079e-05
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.2166e-04 - val_loss: 4.0245e-05
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 1.0044e-04 - val_loss: 3.9198e-05
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.0276e-04 - val_loss: 3.6767e-06
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.1786e-05 - val_loss: 5.4896e-06
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.3162e-05 - val_loss: 5.4663e-05
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.5761e-05 - val_loss: 3.3004e-05
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.3997e-05 - val_loss: 4.3627e-06
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 6.8381e-05 - val_loss: 2.9390e-06
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.1909e-05 - val_loss: 1.6386e-05
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.0609e-05 - val_loss: 3.2127e-06
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.0100e-05 - val_loss: 1.5540e-05
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.8319e-05 - val_loss: 1.9591e-05
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 5.9190e-05 - val_loss: 1.0037e-05
# Predict on X_test.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Predict on X_train.
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Mean Absolute Error (MAE): 1.15
# Root Mean Squared Error (RMSE): 1.32
# Symmetric Mean Absolute Percentage Error (sMAPE): 21.14
# sMAPE: 21.07
# Model saved!
# Training on components: 5
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_23 (Conv1D)              │ (None, 22, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_17 (MaxPooling1D) │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_30 (LSTM)                  │ (None, 11, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_31 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,729 (178.63 KB)
#  Trainable params: 45,729 (178.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0157 - val_loss: 0.0018
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0025 - val_loss: 5.4522e-04
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0014 - val_loss: 4.6385e-04
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0013 - val_loss: 5.6976e-04
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0012 - val_loss: 4.0988e-04
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - val_loss: 3.7655e-04
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0011 - val_loss: 5.0584e-04
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0011 - val_loss: 4.7036e-04
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0011 - val_loss: 3.6509e-04
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0010 - val_loss: 3.4016e-04
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0010 - val_loss: 3.2120e-04
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0010 - val_loss: 3.2490e-04
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.9716e-04 - val_loss: 3.1980e-04
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.8701e-04 - val_loss: 3.3519e-04
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.5946e-04 - val_loss: 3.1095e-04
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.8061e-04 - val_loss: 3.0185e-04
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.5693e-04 - val_loss: 3.0811e-04
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.6637e-04 - val_loss: 3.2189e-04
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.5512e-04 - val_loss: 3.0090e-04
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.5095e-04 - val_loss: 3.2127e-04
# Predict on X_test.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Predict on X_train.
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Mean Absolute Error (MAE): 6.49
# Root Mean Squared Error (RMSE): 9.51
# Symmetric Mean Absolute Percentage Error (sMAPE): 54.72
# sMAPE: 54.55
# Model saved!

# %%
# models = []
# test_preds =[]
# metrics = []
# train_preds = []
# for i in range(sig_comps.shape[1]):
# # for i in range(1):
#     print('components:',i)
#     train_data = train_comps[:,i]
#     test_data = test_comps[:,i]
#     model, y_test_preds, performance, trian_pred_rescaled = cnn_model_ewt_2(train_data, test_data)
    
#     model.save(f'wet_lstm_{i}.keras')
#     print('Model saved!')
#     models.append(model)
#     test_preds.append(y_test_preds)
#     metrics.append(performance)
#     train_preds.append(trian_pred_rescaled)

# %%
def load_ewt_sig(model_name, res = 'test'):
    test_preds_np = np.load(f'ewt_models/{model_name}/{model_name}_{res}_preds.npy')
    return test_preds_np

# %%
MODEL = "CNN"
test_preds_np = load_ewt_sig(MODEL)

# %%
y_test_sig = test_preds_np[:,0,:,:]
y_pred_sig = test_preds_np[:,1,:,:]

# %%
y_test_sig_sum = np.sum(y_test_sig, axis=0).reshape(-1,1)
y_pred_sig_sum = np.sum(y_pred_sig, axis=0).reshape(-1,1)

# %%
def split_test_preds_sing(test_preds_np):
    y_test_sig = test_preds_np[:,0,:,:]
    y_pred_sig = test_preds_np[:,1,:,:]
    y_test_sig_sum = np.sum(y_test_sig, axis=0).reshape(-1,1)
    y_pred_sig_sum = np.sum(y_pred_sig, axis=0).reshape(-1,1) 

    return y_test_sig_sum,y_pred_sig_sum

# %%
y_test_sig_sum,y_pred_sig_sum  = split_test_preds_sing(test_preds_np)

# %%
# Compare pred sig with the decomposed sig
eva_s(y_test_sig_sum.reshape(-1), y_pred_sig_sum.reshape(-1))
# Out:
# Mean Absolute Error (MAE): 17.65
# Root Mean Squared Error (RMSE): 20.29
# Symmetric Mean Absolute Percentage Error (sMAPE): 36.24
# sMAPE: 36.13
# (17.64917975933734, 20.289964845796796, 36.24416103023705, 36.1302791035027)

# %%
# Compare pred sig with the real sig
eva_s(test_df_ewt['price'][24:].to_numpy().reshape(-1), y_pred_sig_sum.reshape(-1))
# Out:
# Mean Absolute Error (MAE): 18.03
# Root Mean Squared Error (RMSE): 20.75
# Symmetric Mean Absolute Percentage Error (sMAPE): 37.00
# sMAPE: 36.89
# (18.027503944149345, 20.750989517230995, 37.002144738909536, 36.88588116937461)

# %%
y_test_1d = test_df_ewt['price'][24:].to_numpy().reshape(-1,1)

# %%
compare_preds(test_df_ewt['price'][24:].to_numpy().reshape(-1,1)[-200:], y_pred_sig_sum[-200:])

# %% [markdown]
# # Error Analysis

# %%
# Error on train dataset
# pred_error_train =

# %%
def train_error(train_preds, real_train_data, length = 100, seq_length =24):
    # Predictions on train data
    train_preds_np = np.asarray(train_preds)
    y_train_sig_sum = np.sum(train_preds_np, axis=0).reshape(-1,1)

    # real data on train set
    real_train = real_train_data[24:].to_numpy().reshape(-1,1)
    print('Overall Performance:')
    eva_s(real_train.reshape(-1), y_train_sig_sum.reshape(-1))
    
    compare_preds(real_train[:length], y_train_sig_sum[:length])

    error_on_train = real_train - y_train_sig_sum

    print('\nShape of prediction errors on train data:',error_on_train.shape)
    print('Seq length:', seq_length)
    return error_on_train

# %%
train_preds = load_ewt_sig(MODEL, res= 'train')

# %%
error_on_train = train_error(train_preds, train_df_ewt['price'])
# Out:
# Overall Performance:
# Mean Absolute Error (MAE): 15.65
# Root Mean Squared Error (RMSE): 22.03
# Symmetric Mean Absolute Percentage Error (sMAPE): 17.12
# sMAPE: 40.92
#
# Shape of prediction errors on train data: (17495, 1)
# Seq length: 24

# %%
def error_to_df(train_df, preds_error, test_df,  drop_col = ['price'], seq = SEQ):
    # Train with x y values for model training
    error_train_xy_df = train_df.drop(columns=drop_col)[SEQ:]
    error_train_xy_df['residual'] = preds_error
    
    # Test with x for test
    error_test_x_df = test_df.drop(columns=drop_col)[SEQ:]
    
    print(error_train_xy_df.info())
    print('------')
    print(error_test_x_df.info())
    
    return error_train_xy_df, error_test_x_df

# %%
error_train_xy_df, error_test_x_df = error_to_df(train_df_ewt, error_on_train ,test_df_ewt, drop_col = ['price'], seq = SEQ )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17495 entries, 2022-01-02 01:00:00 to 2023-12-31 23:00:00
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   solar                    17495 non-null  int64
#  1   wind_onshore             17495 non-null  int64
#  2   wind_offshore            17495 non-null  int64
#  3   total_load               17495 non-null  int64
#  4   actual_solar             17495 non-null  int64
#  5   actual_wind_onshore      17495 non-null  int64
#  6   actual_wind_offshore     17495 non-null  int64
#  7   actual_fossil_gas        17495 non-null  int64
#  8   actual_fossil_hard_coal  17495 non-null  int64
#  9   residual                 17495 non-null  float64
# dtypes: float64(1), int64(9)
# memory usage: 1.5 MB
# None
# ------
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7297 entries, 2024-01-02 00:00:00 to 2024-11-01 00:00:00
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   solar                    7297 non-null   int64
#  1   wind_onshore             7297 non-null   int64
#  2   wind_offshore            7297 non-null   int64
#  3   total_load               7297 non-null   int64
#  4   actual_solar             7297 non-null   int64
#  5   actual_wind_onshore      7297 non-null   int64
#  6   actual_wind_offshore     7297 non-null   int64
#  7   actual_fossil_gas        7297 non-null   int64
#  8   actual_fossil_hard_coal  7297 non-null   int64
# dtypes: int64(9)
# memory usage: 570.1 KB
# None

# %% [markdown]
# ## RELM

# %%
error_train_xy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17495 entries, 2022-01-02 01:00:00 to 2023-12-31 23:00:00
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   solar                    17495 non-null  int64
#  1   wind_onshore             17495 non-null  int64
#  2   wind_offshore            17495 non-null  int64
#  3   total_load               17495 non-null  int64
#  4   actual_solar             17495 non-null  int64
#  5   actual_wind_onshore      17495 non-null  int64
#  6   actual_wind_offshore     17495 non-null  int64
#  7   actual_fossil_gas        17495 non-null  int64
#  8   actual_fossil_hard_coal  17495 non-null  int64
#  9   residual                 17495 non-null  float64
# dtypes: float64(1), int64(9)
# memory usage: 1.5 MB

# %%
def renew_prect(df, renewables, target = 'total_laod'):
    for i in renewables:
        df[f'{i}_prect'] = df[i]/df['total_load']
    return df

# %%
renewables = ['wind_onshore', 'wind_offshore', 'solar']
error_train_xy_df_perct = renew_prect(error_train_xy_df, renewables, target ='total_load')

# %%
error_test_x_df_perct = renew_prect(error_test_x_df, renewables, target ='total_load')

# %%
error_test_x_df_perct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7297 entries, 2024-01-02 00:00:00 to 2024-11-01 00:00:00
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   solar                    7297 non-null   int64
#  1   wind_onshore             7297 non-null   int64
#  2   wind_offshore            7297 non-null   int64
#  3   total_load               7297 non-null   int64
#  4   actual_solar             7297 non-null   int64
#  5   actual_wind_onshore      7297 non-null   int64
#  6   actual_wind_offshore     7297 non-null   int64
#  7   actual_fossil_gas        7297 non-null   int64
#  8   actual_fossil_hard_coal  7297 non-null   int64
#  9   wind_onshore_prect       7297 non-null   float64
#  10  wind_offshore_prect      7297 non-null   float64
#  11  solar_prect              7297 non-null   float64
# dtypes: float64(3), int64(9)
# memory usage: 741.1 KB

# %%
# resi_features = ['wind_onshore', 'wind_offshore', 'solar', 'total_load',  'wind_onshore_prect', 'wind_offshore_prect', 'solar_prect']
resi_features = ['wind_onshore', 'wind_offshore', 'solar', 'total_load']

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Step 1: Prepare the Data
# Assuming error_train_xy_df contains columns: ['residual', 'wind_onshore', 'wind_offshore', 'solar', 'total_load']
features_relm = resi_features
target = 'residual'

X = error_train_xy_df[features_relm].values
y = error_train_xy_df[target].values

# Step 2: Normalize the Data
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

# Step 3: Split the Data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Step 4: Implement RELM
class RELM:
    def __init__(self, n_hidden_neurons, lambda_reg):
        self.n_hidden_neurons = n_hidden_neurons
        self.lambda_reg = lambda_reg

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def fit(self, X, y):
        # Randomly initialize input weights and biases
        self.input_weights = np.random.uniform(-1, 1, (X.shape[1], self.n_hidden_neurons))
        self.biases = np.random.uniform(-1, 1, self.n_hidden_neurons)
        
        # Calculate hidden layer output matrix H
        H = self.sigmoid(np.dot(X, self.input_weights) + self.biases)
        
        # Solve for beta using regularized least squares
        I = np.eye(self.n_hidden_neurons)
        self.beta = np.linalg.inv(H.T @ H + self.lambda_reg * I) @ H.T @ y

    def predict(self, X):
        H = self.sigmoid(np.dot(X, self.input_weights) + self.biases)
        return np.dot(H, self.beta)

# Step 5: Train RELM
relm = RELM(n_hidden_neurons=20, lambda_reg=0.01)  # Adjust `n_hidden_neurons` and `lambda_reg` as needed
relm.fit(X_train, y_train)

# Step 6: Predict and Evaluate
y_pred_train = relm.predict(X_train)
y_pred_test = relm.predict(X_test)

# Inverse transform to get the original scale of the residual
y_pred_train_original = scaler_y.inverse_transform(y_pred_train.reshape(-1, 1))
y_pred_test_original = scaler_y.inverse_transform(y_pred_test.reshape(-1, 1))

# Evaluate the performance
from sklearn.metrics import mean_squared_error

y_train_orininal = scaler_y.inverse_transform(y_train.reshape(-1, 1))
y_test_original = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# train_rmse = np.sqrt(mean_squared_error(scaler_y.inverse_transform(y_train.reshape(-1, 1)), y_pred_train_original))
# test_rmse = np.sqrt(mean_squared_error(scaler_y.inverse_transform(y_test.reshape(-1, 1)), y_pred_test_original))

train_rmse = np.sqrt(mean_squared_error(y_train_orininal, y_pred_train_original))
test_rmse = np.sqrt(mean_squared_error(y_test_original, y_pred_test_original))

print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Train RMSE: 21.85327396002212
# Test RMSE: 21.950718716740326

# %%
compare_preds(y_test_original[:200], y_pred_test_original[:200])

# %% [markdown]
# ## Predict the residual on test data

# %%
# Step 1: Extract Features from the Test Dataset
# features =  error_test_x_df.columns.to_list()
features = resi_features
X_test = error_test_x_df[resi_features].values

# Step 2: Normalize Test Features using the same scaler as the training phase
X_test_scaled = scaler_X.transform(X_test)

# Step 3: Predict Residuals using the Trained RELM Model
residuals_pred_scaled = relm.predict(X_test_scaled)

# Step 4: Inverse Transform the Predicted Residuals to Original Scale
residuals_pred_original = scaler_y.inverse_transform(residuals_pred_scaled.reshape(-1,1))

# Step 5: Add Predicted Residuals to Original Model Predictions (Optional)
# Assuming `original_predictions` are predictions from the first model
# final_predictions = original_predictions + residuals_pred_original

# %%
def updated_preds(pred_residual, prev_preds, y_test, preds_baseline,metrics_baseline):

    print('---Baseline---')
    eva_s(y_test.reshape(-1), preds_baseline)

    print('\n---EWT---')
    
    updated_preds = prev_preds.reshape(-1) + pred_residual.reshape(-1)
    # print('Previous')
    metrics_prev = eva_s(y_test.reshape(-1), prev_preds.reshape(-1))
    print('\n---RELM---')
    metrics_updated = eva_s(y_test.reshape(-1), updated_preds)
    # print(metrics_updated)
    # print('complete')
    print('Prompt Prect')
    print('Baseline:')
    promo_prect(metrics_baseline, metrics_updated)
    print('Prev:')
    promo_prect(metrics_prev, metrics_updated)

# %%
# %run utils.ipynb

# %%
def load_baseline_res(model_name= 'BASELINE' ):
    preds_baseline = np.load(f'ewt_models/{model_name}/{model_name}_preds.npy')
    metrics_baseline = np.load(f'ewt_models/{model_name}/{model_name}_metrics.npy')
    return preds_baseline, metrics_baseline

preds_baseline, metrics_baseline =load_baseline_res()

# %%
updated_preds(residuals_pred_original, y_pred_sig_sum, y_test_1d, preds_baseline = preds_baseline, metrics_baseline=metrics_baseline)
# Out:
# ---Baseline---
# Mean Absolute Error (MAE): 12.30
# Root Mean Squared Error (RMSE): 16.50
# Symmetric Mean Absolute Percentage Error (sMAPE): 30.66
# sMAPE: 30.57
#
# ---EWT---
# Mean Absolute Error (MAE): 18.03
# Root Mean Squared Error (RMSE): 20.75
# Symmetric Mean Absolute Percentage Error (sMAPE): 37.00
# sMAPE: 36.89
#
# ---RELM---
# Mean Absolute Error (MAE): 16.90
# Root Mean Squared Error (RMSE): 19.70
# Symmetric Mean Absolute Percentage Error (sMAPE): 36.06
# sMAPE: 35.95
# Prompt Prect
# Baseline:
# [-37.42042251 -19.40023896 -17.61089172 -17.61089172]
# Prev:
# [6.27492833 5.06023762 2.53621815 2.53621815]

# %%
1ws
# Out:
#   Cell In[52], line 1
#     1ws
#     ^
# SyntaxError: invalid decimal literal

# %%
type(residuals_pred_original)
# Out:
# numpy.ndarray

# %%
# true_value, ewt preds, final preds 
combined_res = np.column_stack((y_test_1d, y_pred_sig_sum, y_pred_sig_sum + residuals_pred_original ))

# %%
combined_res.shape
# Out:
# (7297, 3)

# %%
model_name = MODEL
root_dir = f'ewt_models/{model_name}'
np.save(f"{root_dir}/{model_name}_fin_res.npy", combined_res)
print(f'Save model: {MODEL}')
# Out:
# Save model: CNN

# %%
lstm_res = np.load(f"ewt_models/LSTM/LSTM_fin_res.npy")
gru_res = np.load(f"ewt_models/GRU/GRU_fin_res.npy")
cnn_res = np.load(f"ewt_models/CNN/CNN_fin_res.npy")

# %%
lstm_y_test = lstm_res[:,0]
lstm_y_preds_prev = lstm_res[:,1]
lstm_y_preds_fin = lstm_res[:,2]

gru_y_test = gru_res[:,0]
gru_y_preds_prev = gru_res[:,1]
gru_y_preds_fin = gru_res[:,2]

cnn_y_test = cnn_res[:,0]
cnn_y_preds_prev = cnn_res[:,1]
cnn_y_preds_fin = cnn_res[:,2]

# %% [markdown]
# ## Stat test

# %%
dm_test_cus(y_test, y_preds_fin, preds_baseline)
# Out:
# dm_return(DM=14.337889694668041, p_value=5.3291049745131415e-46)

# %%
dm_test_cus(y_test, y_preds_fin, y_preds_prev)
# Out:
# dm_return(DM=-43.40818573025071, p_value=0.0)

# %%
from dieboldmariano import dm_test
T = y_test_1d.reshape(-1)
F =  y_pred_sig_sum.reshape(-1) 
G = residuals_pred_original.reshape(-1) + y_pred_sig_sum.reshape(-1)
dm_test(T, F, G, one_sided=True)
# Out:
# (33.73063002054295, 1.0)

# %%
from dieboldmariano import dm_test
T = y_test_1d.reshape(-1)
F = y_pred_sig_sum.reshape(-1) 
G = residuals_pred_original.reshape(-1) + y_pred_sig_sum.reshape(-1)
dm_test(T, F, G, one_sided=True)
# Out:
# (33.73063002054295, 1.0)

# %% [markdown]
# ## Vis

# %%
lstm_y_test = lstm_res[:,0]
lstm_y_preds_prev = lstm_res[:,1]
lstm_y_preds_fin = lstm_res[:,2]

gru_y_test = gru_res[:,0]
gru_y_preds_prev = gru_res[:,1]
gru_y_preds_fin = gru_res[:,2]

cnn_y_test = cnn_res[:,0]
cnn_y_preds_prev = cnn_res[:,1]
cnn_y_preds_fin = cnn_res[:,2]

# %%
148 * 20
# Out:
# 2960

# %%
start = 0 * 7 * 24 
end = 1* 7 * 24

fig, axes = plt.subplots(1,3,figsize = (15,5))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
axes[0].plot(lstm_y_test[start:end], 'b-', label='Test')
# ax.plot(lstm_y_preds_fin[start:end], 'g--', label='Predictions (EWT-LTSM-IEWT-RELM)')
axes[0].plot(preds_baseline[start:end], 'y-.', label='Baseline')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
axes[0].legend(loc=2)


start = 19 * 7 * 24
end = 20 * 7 * 24

# fig, axes = plt.subplots(3,1,figsize = (12,8))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
axes[1].plot(lstm_y_test[start:end], 'b-', label='Test')
# ax.plot(lstm_y_preds_fin[start:end], 'g--', label='Predictions (EWT-LTSM-IEWT-RELM)')
axes[1].plot(preds_baseline[start:end], 'y-.', label='Baseline')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
axes[1].legend(loc=2)

start = 41 * 7 * 24
end = 42 * 7 * 24

# fig, axes = plt.subplots(3,1,figsize = (12,8))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
axes[2].plot(lstm_y_test[start:end], 'b-', label='Test')
# ax.plot(lstm_y_preds_fin[start:end], 'g--', label='Predictions (EWT-LTSM-IEWT-RELM)')
axes[2].plot(preds_baseline[start:end], 'y-.', label='Baseline')
axes[2].set_xlabel('Date')
axes[2].set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
axes[2].legend(loc=2)



fig.autofmt_xdate()
plt.tight_layout()

# %%
resi_baseline =  lstm_y_test - preds_baseline
resi_lstm =  lstm_y_test - lstm_y_preds_fin
resi_gru =  gru_y_test - gru_y_preds_fin
resi_cnn =  cnn_y_test - cnn_y_preds_fin

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(resi_baseline, line='s')

# %%
import scipy.stats as stats

# Create QQ plot against normal distribution
stats.probplot(resi_baseline, dist="norm", plot=plt)
plt.title("QQ Plot (Normal Distribution)")
plt.show()

# %%
import scipy.stats as stats

# Create QQ plot against normal distribution
stats.probplot(resi_lstm, dist="norm", plot=plt)
plt.title("QQ Plot (Normal Distribution)")
plt.show()

# %%
import scipy.stats as stats

# Create QQ plot against normal distribution
stats.probplot(resi_gru, dist="norm", plot=plt)
plt.title("QQ Plot (Normal Distribution)")
plt.show()

# %%
# continue
preds_baseline.shape
# Out:
# (7297,)

# %%
date_index_test = test_df_ewt.iloc[24:, ].shape
# Out:
# (7297, 10)

# %%
start = 0
end = 300

fig, ax = plt.subplots(figsize = (12,8))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
ax.plot(gru_y_test[start:end], 'b-', label='Test')
ax.plot(gru_y_preds_fin[start:end], 'g--', label='Predictions (EWT-GRU-IEWT-RELM)')
ax.plot(preds_baseline[start:end], 'y-.', label='Baseline')
ax.set_xlabel('Date')
ax.set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
ax.legend(loc=2)


fig.autofmt_xdate()
plt.tight_layout()

# %%
24 * 7
# Out:
# 168

# %%
start = 5000
end = 5168

fig, ax = plt.subplots(figsize = (12,8))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
ax.plot(lstm_y_test[start:end], 'b-', label='Test')
ax.plot(lstm_y_preds_fin[start:end], 'g--', label='Predictions (EWT-LTSM-IEWT-RELM)')
ax.plot(preds_baseline[start:end], 'y-.', label='Baseline')
ax.set_xlabel('Date')
ax.set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
ax.legend(loc=2)


fig.autofmt_xdate()
plt.tight_layout()

# %%
start = 5000
end = 5168

fig, ax = plt.subplots(figsize = (12,8))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
ax.plot(lstm_y_test[start:end], 'b-', label='Test')
ax.plot(lstm_y_preds_fin[start:end], 'g--', label='Predictions (EWT-LTSM-IEWT-RELM)')
ax.plot(preds_baseline[start:end], 'y-.', label='Baseline')
ax.set_xlabel('Date')
ax.set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
ax.legend(loc=2)


fig.autofmt_xdate()
plt.tight_layout()

# %%
start = 5000
end = 5168

fig, ax = plt.subplots(figsize = (12,8))
# ax.plot(train['date'], train['data'], 'g-.', label='Train')
ax.plot(cnn_y_test[start:end], 'b-', label='Test')
ax.plot(cnn_y_preds_fin[start:end], 'g--', label='Predictions (EWT-LTSM-IEWT-RELM)')
ax.plot(preds_baseline[start:end], 'y-.', label='Baseline')
ax.set_xlabel('Date')
ax.set_ylabel('Electricity Price')
# ax.axvspan(80, 83, color='#808080', alpha=0.2)
ax.legend(loc=2)


fig.autofmt_xdate()
plt.tight_layout()

# %%
q1 = np.percentile(abs(cnn_y_test), 25)

# Calculate the 3rd quartile (75th percentile)
q3 = np.percentile(abs(cnn_y_test), 75)

# Calculate the IQR
iqr = q3 - q1

print(iqr)
# Out:
# 40.8

# %%
q1
# Out:
# 54.0

# %%
q3
# Out:
# 94.8

# %%
final_error.shape
# Out:
# (7297, 1)

# %%
test_df_ewt.shape
# Out:
# (7321, 10)

# %%
7321 - 24
# Out:
# 7297

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# Step 1: Prepare the data
features = ['wind_onshore', 'wind_offshore', 'solar', 'total_load']
target = 'residual'

X = error_train_xy_df[features].values  # Features
y = error_train_xy_df[target].values   # Residuals

# Step 2: Normalize the data
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

# Step 3: Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Step 4: Train an SVM Regressor
svm = SVR(kernel='rbf', C=1.0, epsilon=0.1)  # Adjust hyperparameters as needed
svm.fit(X_train, y_train)

# Step 5: Predict residuals
y_pred_scaled = svm.predict(X_test)

# Step 6: Inverse transform predictions to the original scale
y_pred_original = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1))

# # Step 7: Combine with the original model's predictions
# # Assuming `original_predictions` are the predictions from the first model
# final_predictions = original_predictions + y_pred_original

# # Step 8: Evaluate the performance
# test_rmse = np.sqrt(mean_squared_error(scaler_y.inverse_transform(y_test), y_pred_original))
# print(f"Test RMSE: {test_rmse}")

# %%
# Step 1: Extract Features from the Test Dataset
# features =  error_test_x_df.columns.to_list()
# features = resi_features
X_test = error_test_x_df[features].values

# Step 2: Normalize Test Features using the same scaler as the training phase
X_test_scaled = scaler_X.transform(X_test)

# Step 3: Predict Residuals using the Trained RELM Model
residuals_pred_scaled = svm.predict(X_test_scaled)

# Step 4: Inverse Transform the Predicted Residuals to Original Scale
residuals_pred_original = scaler_y.inverse_transform(residuals_pred_scaled.reshape(-1,1))

# Step 5: Add Predicted Residuals to Original Model Predictions (Optional)
# Assuming `original_predictions` are predictions from the first model
# final_predictions = original_predictions + residuals_pred_original

# %%
updated_preds(residuals_pred_original, y_pred_sig_sum, y_test_1d)
# Out:
# Mean Absolute Error (MAE): 9.55
# Root Mean Squared Error (RMSE): 12.09
# Symmetric Mean Absolute Percentage Error (sMAPE): 25.69
# ----------
# Mean Absolute Error (MAE): 7.37
# Root Mean Squared Error (RMSE): 10.21
# Symmetric Mean Absolute Percentage Error (sMAPE): 22.85
# [22.87137894 15.53812804 11.05126971]

# %%
adj_preds = residuals_pred_original + y_pred_sig_sum

# %%
resi_new = y_test_1d - adj_preds

# %%
plt.figure(figsize=(12,6))
plt.plot(resi_new)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import numpy as np

# Step 1: Prepare the data
features = ['wind_onshore', 'wind_offshore', 'solar', 'total_load']
target = 'residual'

X = error_train_xy_df[features].values  # Features
y = error_train_xy_df[target].values   # Residuals

# Step 2: Normalize the features (Optional for Random Forest)
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# Step 3: Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Step 4: Train the Random Forest Regressor
rf = RandomForestRegressor(n_estimators=300, max_depth=30, random_state=42)  # Adjust hyperparameters as needed
rf.fit(X_train, y_train)

# Step 5: Predict the residuals for the test set
y_pred_rf = rf.predict(X_test)

# # Step 6: Combine predicted residuals with original model's predictions
# # Assuming `original_predictions` are the predictions from the first model
# final_predictions = original_predictions + y_pred

# # Step 7: Evaluate the performance
# rmse = np.sqrt(mean_squared_error(y_test, y_pred))
# print(f"Test RMSE: {rmse}")

# %%
# Step 1: Extract Features from the Test Dataset
# features =  error_test_x_df.columns.to_list()
# features = resi_features
X_test = error_test_x_df[features].values

# Step 2: Normalize Test Features using the same scaler as the training phase
X_test_scaled = scaler_X.transform(X_test)

# Step 3: Predict Residuals using the Trained RELM Model
residuals_pred_scaled = rf.predict(X_test_scaled)

# %%
# Extract feature importances
feature_importances = rf.feature_importances_

# Display in a DataFrame
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#          Feature  Importance
# 3     total_load    0.283138
# 1  wind_offshore    0.273964
# 0   wind_onshore    0.273035
# 2          solar    0.169864

# %%
import shap
# Create a SHAP explainer
explainer = shap.TreeExplainer(rf)
# Compute SHAP values for the dataset
shap_values = explainer.shap_values(X_test)

# %%
updated_preds(residuals_pred_original, y_pred_sig_sum, y_test_1d)
# Out:
# Mean Absolute Error (MAE): 9.55
# Root Mean Squared Error (RMSE): 12.09
# Symmetric Mean Absolute Percentage Error (sMAPE): 25.69
# ----------
# Mean Absolute Error (MAE): 7.37
# Root Mean Squared Error (RMSE): 10.21
# Symmetric Mean Absolute Percentage Error (sMAPE): 22.85
# [22.87137894 15.53812804 11.05126971]

# %% [markdown]
# ## Decompose features

# %%
sig_comps_windon = ewt_trans(error_train_xy_df['wind_onshore'], level = 6, lengthFilter= 1, reg = 'none', sigmaFilter=5)

# %%
import pandas as pd

# def ewt_decompose(series, n_modes=5):
#     """
#     Decomposes a single time series into sub-bands using EWT.
    
#     Parameters:
#     - series: array-like, shape (n_samples,)
#       The input time series to decompose.
#     - n_modes: int, default=5
#       The number of modes (sub-bands) to extract.
    
#     Returns:
#     - imfs: array-like, shape (n_samples, n_modes)
#       The decomposed sub-bands.
#     """
#     # Example implementation for EWT decomposition
#     # Replace this with your actual EWT implementation
#     import numpy as np
#     from PyEMD import EMD  # Example using Empirical Mode Decomposition
#     emd = EMD()
#     imfs = emd(series)
#     return imfs[:, :n_modes]  # Limit to `n_modes` if needed

# def ewt_decompose(data, K=6, log = 0, detect = "locmax", completion = 0, reg = 'none', lengthFilter = 1,sigmaFilter = 0):

def add_ewt_features(dataframe, features, n_modes=5):
    """
    Decomposes selected features in the dataframe using EWT and adds decomposed sub-bands as new features.
    
    Parameters:
    - dataframe: pd.DataFrame
      The input dataframe containing the features to decompose.
    - features: list of str
      The names of the columns to decompose.
    - n_modes: int, default=5
      The number of modes (sub-bands) to extract for each feature.
    
    Returns:
    - dataframe: pd.DataFrame
      The dataframe with the decomposed sub-bands added as new columns.
    """
    for feature in features:
        print(f"Decomposing feature: {feature}")
        # Apply EWT decomposition
        _, imfs = ewt_decompose(dataframe[feature].values, K=n_modes, log = 0, detect = "locmax", completion = 0, reg = 'none', lengthFilter = 1,sigmaFilter = 0)

        # print(len(imfs))
        # Add each sub-band as a new feature
        for i in range(imfs.shape[1]):
            new_column_name = f"{feature}_ewt_mode_{i+1}"
            dataframe[new_column_name] = imfs[:, i]
    
    return dataframe


# Example Usage
# Assuming `df` is your dataframe and you want to decompose 4 features
features_to_decompose = ['wind_onshore', 'wind_offshore', 'solar', 'total_load']
n_modes = 6  # Number of sub-bands to extract

# Add EWT-decomposed features to the dataframe
df_with_ewt = add_ewt_features(error_train_xy_df, features_to_decompose, n_modes=n_modes)

# Check the updated dataframe
# print(df_with_ewt.head())

# %%
error_test_with_ewt = add_ewt_features(error_test_x_df, features_to_decompose, n_modes=n_modes)

# %%
df_with_ewt.info()

# %%
ewt_features = df_with_ewt.columns.to_list()
ewt_features.remove('residual')
ewt_features

# %%
import pandas as pd
import numpy as np

# 1. Prepare the Data
# Assuming 'df_with_ewt' is your dataframe with EWT-decomposed features
# And 'residual' is the target variable in your dataframe

# Select features (exclude non-numeric columns and the target variable)
X = df_with_ewt.drop(columns=['residual']).values
y = df_with_ewt['residual'].values

# 2. Split the Data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 3. Scale the Data
from sklearn.preprocessing import StandardScaler

# Scale features
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Scale target variable
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()

# 4. Train the SVR Model
from sklearn.svm import SVR

svr = SVR(kernel='rbf', C=10.0, epsilon=0.1)  # Hyperparameters to tune
svr.fit(X_train_scaled, y_train_scaled)

# 5. Predict and Evaluate
# Predict on the test set
y_pred_scaled = svr.predict(X_test_scaled)

# Inverse transform the predictions
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1))

# Evaluate the model
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"SVR Mean Squared Error: {mse}")
print(f"SVR Mean Absolute Error: {mae}")

# %%
compare_preds(y_test[-300:],y_pred[-300:])

# %%
# Step 1: Extract Features from the Test Dataset
# features =  error_test_x_df.columns.to_list()
# features = resi_features
X_test = error_test_with_ewt[ewt_features].values

# Step 2: Normalize Test Features using the same scaler as the training phase
X_test_scaled = scaler_X.transform(X_test)

# Step 3: Predict Residuals using the Trained RELM Model
residuals_pred_scaled = svr.predict(X_test_scaled)

# Step 4: Inverse Transform the Predicted Residuals to Original Scale
residuals_pred_original = scaler_y.inverse_transform(residuals_pred_scaled.reshape(-1,1))

# Step 5: Add Predicted Residuals to Original Model Predictions (Optional)
# Assuming `original_predictions` are predictions from the first model
# final_predictions = original_predictions + residuals_pred_original

# %%
updated_preds(residuals_pred_original, y_pred_sig_sum, y_test_1d)
